# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set();

# %%
df1=pd.read_csv('IT Salary Survey EU  2020.csv')
df1.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# 1                                        Ruby
# 2                     Javascript / Typescript
# 3                                  Javascript
# 4                                     C# .NET
#
#   Other technologies/programming languages you use often  ...  \
# 0                    Kotlin, Javascript / Typescript      ...
# 1                                                NaN      ...
# 2                    Javascript / Typescript, Docker      ...
# 3                                                NaN      ...
# 4                             .NET, SQL, AWS, Docker      ...
#
#    Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days           Employment status   Сontract duration  \
# 0                      30          Full-time employee  Unlimited contract
# 1                      28          Full-time employee  Unlimited contract
# 2                      30  Self-employed (freelancer)  Temporary contract
# 3                      24          Full-time employee  Unlimited contract
# 4                      29          Full-time employee  Unlimited contract
#
#   Main language at work Company size Company type  \
# 0               English       51-100      Product
# 1               English     101-1000      Product
# 2               English     101-1000      Product
# 3               English       51-100      Startup
# 4               English     101-1000      Product
#
#   Have you lost your job due to the coronavirus outbreak?  \
# 0                                                 No
# 1                                                 No
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
df1.shape
# Out:
# (1253, 23)

# %%
df1.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
#        'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# Seniority level                                                                                                             12
# Your main technology / programming language                                                                                127
# Other technologies/programming languages you use often                                                                     157
# Yearly brutto salary (without bonus and stocks) in EUR                                                                       0
# Yearly bonus + stocks in EUR                                                                                               424
# Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country                   368
# Annual bonus+stocks one year ago. Only answer if staying in same country                                                   639
# Number of vacation days                                                                                                     68
# Employment status                                                                                                           17
# Сontract duration                                                                                                           29
# Main language at work                                                                                                       16
# Company size                                                                                                                18
# Company type                                                                                                                25
# Have you lost your job due to the coronavirus outbreak?                                                                     20
# Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week                          880
# Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR    791
# dtype: int64

# %%
missing=df1.isnull().sum()*100/len(df1)
missing_values_df=pd.DataFrame({'%missing':missing,
                                'columns': df1.columns})
missing_values_df
# Out:
#                                                      %missing  \
# Timestamp                                            0.000000
# Age                                                  2.154828
# Gender                                               0.798085
# City                                                 0.000000
# Position                                             0.478851
# Total years of experience                            1.276935
# Years of experience in Germany                       2.553871
# Seniority level                                      0.957702
# Your main technology / programming language         10.135674
# Other technologies/programming languages you us...  12.529928
# Yearly brutto salary (without bonus and stocks)...   0.000000
# Yearly bonus + stocks in EUR                        33.838787
# Annual brutto salary (without bonus and stocks)...  29.369513
# Annual bonus+stocks one year ago. Only answer i...  50.997606
# Number of vacation days                              5.426975
# Employment status                                    1.356744
# Сontract duration                                    2.314445
# Main language at work                                1.276935
# Company size                                         1.436552
# Company type                                         1.995211
# Have you lost your job due to the coronavirus o...   1.596169
# Have you been forced to have a shorter working ...  70.231445
# Have you received additional monetary support f...  63.128492
#
#                                                                                               columns
# Timestamp                                                                                   Timestamp
# Age                                                                                               Age
# Gender                                                                                         Gender
# City                                                                                             City
# Position                                                                                    Position
# Total years of experience                                                   Total years of experience
# Years of experience in Germany                                         Years of experience in Germany
# Seniority level                                                                       Seniority level
# Your main technology / programming language               Your main technology / programming language
# Other technologies/programming languages you us...  Other technologies/programming languages you u...
# Yearly brutto salary (without bonus and stocks)...  Yearly brutto salary (without bonus and stocks...
# Yearly bonus + stocks in EUR                                             Yearly bonus + stocks in EUR
# Annual brutto salary (without bonus and stocks)...  Annual brutto salary (without bonus and stocks...
# Annual bonus+stocks one year ago. Only answer i...  Annual bonus+stocks one year ago. Only answer ...
# Number of vacation days                                                       Number of vacation days
# Employment status                                                                   Employment status
# Сontract duration                                                                   Сontract duration
# Main language at work                                                           Main language at work
# Company size                                                                             Company size
# Company type                                                                             Company type
# Have you lost your job due to the coronavirus o...  Have you lost your job due to the coronavirus ...
# Have you been forced to have a shorter working ...  Have you been forced to have a shorter working...
# Have you received additional monetary support f...  Have you received additional monetary support ...

# %%
df1.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# min                                         1.100000e+04
# 25%                                         5.500000e+04
# 50%                                         6.500000e+04
# 75%                                         7.500000e+04
# max                                         5.000000e+08
#
#        Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week
# count                                         373.000000
# mean                                           12.967828
# std                                            15.275174
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            30.000000
# max                                            40.000000

# %%
df1.Gender.value_counts().plot(kind='bar')
plt.title('Respondents Gender');

# %%
df1.Age.mean()
# Out:
# 32.50978792822186

# %%
df1.groupby('Gender').describe()
# Out:
#             Age                                                       \
#           count       mean       std   min    25%   50%    75%   max
# Gender
# Diverse     2.0  27.500000  7.778175  22.0  24.75  27.5  30.25  33.0
# Female    191.0  31.261780  4.709962  21.0  28.00  31.0  34.00  45.0
# Male     1030.0  32.740777  5.793648  20.0  29.00  32.0  36.00  69.0
#
#         Yearly brutto salary (without bonus and stocks) in EUR                \
#                                                          count          mean
# Gender
# Diverse                                                2.0      1.445000e+05
# Female                                               192.0      2.662480e+06
# Male                                                1049.0      7.384706e+04
#
#          ...  \
#          ...
# Gender   ...
# Diverse  ...
# Female   ...
# Male     ...
#
#         Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
#                                                                                                              75%
# Gender
# Diverse                                            98000.0
# Female                                             62750.0
# Male                                               78000.0
#
#                       \
#                  max
# Gender
# Diverse      98000.0
# Female   500000000.0
# Male        760000.0
#
#         Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week  \
#                                                                                                     count
# Gender
# Diverse                                                1.0
# Female                                                53.0
# Male                                                 318.0
#
#
#               mean        std   min   25%   50%   75%   max
# Gender
# Diverse  30.000000        NaN  30.0  30.0  30.0  30.0  30.0
# Female   11.783019  15.543212   0.0   0.0   0.0  30.0  40.0
# Male     13.152516  15.246953   0.0   0.0   0.0  30.0  40.0
#
# [3 rows x 32 columns]

# %%
df1.groupby('Employment status')['Gender'].describe()
# Out:
#                                                    count unique     top  freq
# Employment status
# Company Director                                       1      1    Male     1
# Founder                                                3      1    Male     3
# Full-time employee                                  1184      3    Male  1001
# Full-time position, part-time position, & self-...     1      1    Male     1
# Intern                                                 1      1    Male     1
# Part-time employee                                     8      2  Female     5
# Self-employed (freelancer)                            28      2    Male    27
# Werkstudent                                            1      1    Male     1
# Working Student                                        1      1    Male     1
# full-time, but 32 hours per week (it was my req...     1      1  Female     1
# working student                                        1      1  Female     1

# %%
df1.Timestamp.describe()
# Out:
# count                    1253
# unique                   1248
# top       24/11/2020 13:55:19
# freq                        2
# Name: Timestamp, dtype: object

# %%
df1.pivot_table(['Age'], index='Total years of experience', columns='Gender')
# Out:
#                                                        Age             \
# Gender                                             Diverse     Female
# Total years of experience
# 0                                                      NaN  29.000000
# 0.8                                                    NaN        NaN
# 1                                                     27.5  28.818182
# 1 (as QA Engineer) / 11 in total                       NaN  34.000000
# 1,5                                                    NaN  37.500000
# 1.5                                                    NaN  25.000000
# 10                                                     NaN  33.266667
# 11                                                     NaN  34.200000
# 12                                                     NaN  37.800000
# 13                                                     NaN  37.000000
# 14                                                     NaN  35.250000
# 15                                                     NaN  38.333333
# 15, thereof 8 as CTO                                   NaN        NaN
# 16                                                     NaN  40.000000
# 17                                                     NaN        NaN
# 18                                                     NaN        NaN
# 19                                                     NaN        NaN
# 2                                                      NaN  29.105263
# 2,5                                                    NaN  26.000000
# 2.5                                                    NaN  39.000000
# 20                                                     NaN  41.000000
# 21                                                     NaN        NaN
# 22                                                     NaN        NaN
# 23                                                     NaN        NaN
# 24                                                     NaN        NaN
# 25                                                     NaN        NaN
# 26                                                     NaN        NaN
# 27                                                     NaN        NaN
# 28                                                     NaN        NaN
# 29                                                     NaN        NaN
# 3                                                      NaN  28.066667
# 3.5                                                    NaN        NaN
# 30                                                     NaN        NaN
# 31                                                     NaN        NaN
# 383                                                    NaN        NaN
# 4                                                      NaN  28.444444
# 4.5                                                    NaN        NaN
# 40                                                     NaN        NaN
# 5                                                      NaN  31.000000
# 5.5                                                    NaN        NaN
# 6                                                      NaN  30.900000
# 6 (not as a data scientist, but as a lab scient...     NaN        NaN
# 6.5                                                    NaN  33.000000
# 7                                                      NaN  31.090909
# 8                                                      NaN  31.277778
# 9                                                      NaN  32.142857
# less than year                                         NaN  24.000000
#
#
# Gender                                                   Male
# Total years of experience
# 0                                                   27.200000
# 0.8                                                 24.000000
# 1                                                   27.941176
# 1 (as QA Engineer) / 11 in total                          NaN
# 1,5                                                       NaN
# 1.5                                                 26.000000
# 10                                                  33.633333
# 11                                                  33.216216
# 12                                                  35.442623
# 13                                                  35.485714
# 14                                                  35.676471
# 15                                                  37.526316
# 15, thereof 8 as CTO                                36.000000
# 16                                                  37.052632
# 17                                                  37.166667
# 18                                                  39.733333
# 19                                                  40.714286
# 2                                                   28.567568
# 2,5                                                       NaN
# 2.5                                                 27.666667
# 20                                                  40.653846
# 21                                                  42.333333
# 22                                                  42.800000
# 23                                                  47.000000
# 24                                                  38.000000
# 25                                                  49.833333
# 26                                                  45.000000
# 27                                                  47.000000
# 28                                                  44.000000
# 29                                                  50.000000
# 3                                                   27.686275
# 3.5                                                 29.000000
# 30                                                  52.750000
# 31                                                  54.000000
# 383                                                 69.000000
# 4                                                   29.050000
# 4.5                                                 27.500000
# 40                                                  66.000000
# 5                                                   29.267857
# 5.5                                                 26.000000
# 6                                                   30.435897
# 6 (not as a data scientist, but as a lab scient...  31.000000
# 6.5                                                       NaN
# 7                                                   30.397260
# 8                                                   30.684932
# 9                                                   31.615385
# less than year                                            NaN

# %%
df1.pivot_table(['Age'], index='Total years of experience',
                aggfunc='mean').plot()
plt.ylabel('AGE');

# %%
#Checking unique values in the dataset
df1.apply(lambda x: len(x.unique()))
# Out:
# Timestamp                                                                                                                  1248
# Age                                                                                                                          41
# Gender                                                                                                                        4
# City                                                                                                                        119
# Position                                                                                                                    149
# Total years of experience                                                                                                    49
# Years of experience in Germany                                                                                               54
# Seniority level                                                                                                              25
# Your main technology / programming language                                                                                 257
# Other technologies/programming languages you use often                                                                      563
# Yearly brutto salary (without bonus and stocks) in EUR                                                                      201
# Yearly bonus + stocks in EUR                                                                                                169
# Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country                    148
# Annual bonus+stocks one year ago. Only answer if staying in same country                                                    132
# Number of vacation days                                                                                                      46
# Employment status                                                                                                            12
# Сontract duration                                                                                                             4
# Main language at work                                                                                                        15
# Company size                                                                                                                  6
# Company type                                                                                                                 64
# Have you lost your job due to the coronavirus outbreak?                                                                      11
# Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week                            24
# Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR      60
# dtype: int64

# %%
plt.figure(figsize=(10,5))
df1['Employment status'].value_counts().plot(kind='bar')
plt.ylabel('Counts')
plt.xlabel('Employment Status');

# %% [markdown]
# ##### looks like most people are full-time employees

# %%
print(df1['Your main technology / programming language'].value_counts()>20)
plt.figure(figsize=(10,8))
df1['Your main technology / programming language'].value_counts().plot(kind='hist')
plt.title('Number of developers as per their main technology')
plt.ylabel('Counts')
plt.xlabel('Programming Language');

# %%
df2=pd.read_csv('T Salary Survey EU 2019.csv')
df2.head()
# Out:
#            Zeitstempel   Age Gender    City Seniority level  \
# 0  02.12.2019 11:18:26  33.0   Male  Berlin          Senior
# 1  02.12.2019 11:18:35  29.0   Male  Berlin          Middle
# 2  02.12.2019 11:18:56   NaN   Male  Berlin          Middle
# 3  02.12.2019 11:19:08  30.0   Male  Berlin          Senior
# 4  02.12.2019 11:19:37  32.0   Male  Berlin          Senior
#
#   Position (without seniority)  Years of experience  \
# 0          Fullstack Developer                   13
# 1            Backend Developer                    3
# 2             Mobile Developer                    4
# 3            Backend Developer                    6
# 4           Embedded Developer                   10
#
#   Your main technology / programming language  \
# 0                                         PHP
# 1                                      Python
# 2                                      Kotlin
# 3                                         PHP
# 4                                       C/C++
#
#    Yearly brutto salary (without bonus and stocks)  Yearly bonus  ...  \
# 0                                          64000.0        1000.0  ...
# 1                                          55000.0           NaN  ...
# 2                                          70000.0           NaN  ...
# 3                                          63000.0           NaN  ...
# 4                                          66000.0           NaN  ...
#
#    Yearly stocks one year ago. Only answer if staying in same country  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Number of vacation days  Number of home office days per month  \
# 0                     29.0                                   4.0
# 1                     22.0                                   4.0
# 2                     27.0                                   NaN
# 3                     24.0                                   NaN
# 4                     30.0                                   0.0
#
#    Main language at work  Company name   Company size Company type  \
# 0                English            NaN        50-100      Startup
# 1                English            NaN         10-50      Product
# 2                English            NaN         1000+      Startup
# 3                English          Auto1      100-1000      Product
# 4                English         Luxoft        50-100      Product
#
#   Сontract duration Company business sector   0
# 0         unlimited                 Tourism NaN
# 1         unlimited   Scientific Activities NaN
# 2         unlimited                     NaN NaN
# 3         unlimited               Transport NaN
# 4         unlimited              Automotive NaN
#
# [5 rows x 23 columns]

# %%
df2.tail()
# Out:
#              Zeitstempel   Age Gender       City Seniority level  \
# 986  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 987  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 988  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 989  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 990  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#     Position (without seniority)  Years of experience  \
# 986            Backend Developer                   10
# 987            Security Engineer                    7
# 988                      Manager                    9
# 989           Software Architect                   15
# 990          Fullstack Developer                    5
#
#     Your main technology / programming language  \
# 986                                      Python
# 987                                Not Relevant
# 988                                Not Relevant
# 989                     Javascript / Typescript
# 990                                        Java
#
#      Yearly brutto salary (without bonus and stocks)  Yearly bonus  ...  \
# 986                                          71000.0        3000.0  ...
# 987                                          72000.0           0.0  ...
# 988                                          68000.0       10000.0  ...
# 989                                         100000.0        3000.0  ...
# 990                                          63000.0           NaN  ...
#
#      Yearly stocks one year ago. Only answer if staying in same country  \
# 986                                                0.0
# 987                                                0.0
# 988                                                NaN
# 989                                                NaN
# 990                                                NaN
#
#      Number of vacation days  Number of home office days per month  \
# 986                     25.0                                   5.0
# 987                     27.0                                   5.0
# 988                     30.0                                   5.0
# 989                     26.0                                   6.0
# 990                     30.0                                   5.0
#
#      Main language at work  Company name   Company size         Company type  \
# 986                English            NaN         1000+              Product
# 987                English            ING         1000+                 Bank
# 988                English            SAP         1000+              Product
# 989                English            NaN         1000+              Product
# 990                Deutsch            NaN         1000+  Consulting / Agency
#
#     Сontract duration Company business sector   0
# 986         unlimited                 Telecom NaN
# 987         unlimited     Finance / Insurance NaN
# 988         unlimited                Сommerce NaN
# 989  more than 1 year                  Health NaN
# 990         unlimited               Transport NaN
#
# [5 rows x 23 columns]

# %%
df2.shape, df2.size
# Out:
# ((991, 23), 22793)

# %%
df2.describe()
# Out:
#               Age  Years of experience  \
# count  882.000000           991.000000
# mean    32.416100             8.529768
# std      5.262496             5.036320
# min     20.000000             0.000000
# 25%     29.000000             5.000000
# 50%     32.000000             8.000000
# 75%     35.000000            11.000000
# max     54.000000            30.000000
#
#        Yearly brutto salary (without bonus and stocks)  Yearly bonus  \
# count                                       990.000000    530.000000
# mean                                      72562.212121   7857.169811
# std                                       23947.379182  10320.628344
# min                                        6000.000000      0.000000
# 25%                                       60000.000000    300.000000
# 50%                                       70000.000000   5000.000000
# 75%                                       80000.000000  10000.000000
# max                                      216000.000000  80000.000000
#
#        Yearly stocks  \
# count     203.000000
# mean    18263.119803
# std     61012.387773
# min         0.000000
# 25%         1.000000
# 50%      2000.000000
# 75%     20000.000000
# max    750000.000000
#
#        Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country  \
# count                                         603.000000
# mean                                        65803.895522
# std                                         20554.017614
# min                                             0.000000
# 25%                                         55000.000000
# 50%                                         65000.000000
# 75%                                         75000.000000
# max                                        200000.000000
#
#        Yearly bonus one year ago. Only answer if staying in same country  \
# count                                         257.000000
# mean                                         8144.000000
# std                                         15067.876701
# min                                             0.000000
# 25%                                          1000.000000
# 50%                                          5000.000000
# 75%                                          9000.000000
# max                                        150000.000000
#
#        Yearly stocks one year ago. Only answer if staying in same country  \
# count                                         139.000000
# mean                                         8204.476331
# std                                         45224.397374
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.100000
# 75%                                          3000.000000
# max                                        520000.000000
#
#        Number of vacation days  Number of home office days per month    0
# count               931.000000                            639.000000  0.0
# mean                 27.924812                              6.462050  NaN
# std                   4.482911                             15.384601  NaN
# min                   4.000000                              0.000000  NaN
# 25%                  26.000000                              2.000000  NaN
# 50%                  28.000000                              4.000000  NaN
# 75%                  30.000000                              7.000000  NaN
# max                 100.000000                            365.000000  NaN

# %%
df2.columns
# Out:
# Index(['Zeitstempel', 'Age', 'Gender', 'City', 'Seniority level',
#        'Position (without seniority)', 'Years of experience',
#        'Your main technology / programming language',
#        'Yearly brutto salary (without bonus and stocks)', 'Yearly bonus',
#        'Yearly stocks',
#        'Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country',
#        'Yearly bonus one year ago. Only answer if staying in same country',
#        'Yearly stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Number of home office days per month',
#        'Main language at work', 'Company name ', 'Company size',
#        'Company type', 'Сontract duration', 'Company business sector', '0'],
#       dtype='object')

# %%
df2.apply(lambda x: len(x.unique()))
# Out:
# Zeitstempel                                                                                             991
# Age                                                                                                      34
# Gender                                                                                                    2
# City                                                                                                     76
# Seniority level                                                                                           7
# Position (without seniority)                                                                             52
# Years of experience                                                                                      26
# Your main technology / programming language                                                              43
# Yearly brutto salary (without bonus and stocks)                                                         174
# Yearly bonus                                                                                             92
# Yearly stocks                                                                                            62
# Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country    129
# Yearly bonus one year ago. Only answer if staying in same country                                        65
# Yearly stocks one year ago. Only answer if staying in same country                                       32
# Number of vacation days                                                                                  33
# Number of home office days per month                                                                     22
# Main language at work                                                                                    12
# Company name                                                                                            221
# Company size                                                                                              6
# Company type                                                                                              8
# Сontract duration                                                                                         7
# Company business sector                                                                                  53
# 0                                                                                                         1
# dtype: int64

# %%
df2.info
# Out:
# <bound method DataFrame.info of              Zeitstempel   Age Gender       City Seniority level  \
# 0    02.12.2019 11:18:26  33.0   Male     Berlin          Senior
# 1    02.12.2019 11:18:35  29.0   Male     Berlin          Middle
# 2    02.12.2019 11:18:56   NaN   Male     Berlin          Middle
# 3    02.12.2019 11:19:08  30.0   Male     Berlin          Senior
# 4    02.12.2019 11:19:37  32.0   Male     Berlin          Senior
# ..                   ...   ...    ...        ...             ...
# 986  07.01.2020 09:23:01  30.0   Male  Amsterdam          Senior
# 987  07.01.2020 10:08:18  28.0   Male  Amsterdam          Senior
# 988  07.01.2020 16:52:43  42.0   Male     Munich          Senior
# 989  08.01.2020 11:18:41  33.0   Male     Berlin          Senior
# 990  08.01.2020 22:20:08  32.0   Male  Frankfurt          Middle
#
#     Position (without seniority)  Years of experience  \
# 0            Fullstack Developer                   13
# 1              Backend Developer                    3
# 2               Mobile Developer                    4
# 3              Backend Developer                    6
# 4             Embedded Developer                   10
# ..                           ...                  ...
# 986            Backend Developer                   10
# 987            Security Engineer                    7
# 988                      Manager                    9
# 989           Software Architect                   15
# 990          Fullstack Developer                    5
#
#     Your main technology / programming language  \
# 0                                           PHP
# 1                                        Python
# 2                                        Kotlin
# 3                                           PHP
# 4                                         C/C++
# ..                                          ...
# 986                                      Python
# 987                                Not Relevant
# 988                                Not Relevant
# 989                     Javascript / Typescript
# 990                                        Java
#
#      Yearly brutto salary (without bonus and stocks)  Yearly bonus  ...  \
# 0                                            64000.0        1000.0  ...
# 1                                            55000.0           NaN  ...
# 2                                            70000.0           NaN  ...
# 3                                            63000.0           NaN  ...
# 4                                            66000.0           NaN  ...
# ..                                               ...           ...  ...
# 986                                          71000.0        3000.0  ...
# 987                                          72000.0           0.0  ...
# 988                                          68000.0       10000.0  ...
# 989                                         100000.0        3000.0  ...
# 990                                          63000.0           NaN  ...
#
#      Yearly stocks one year ago. Only answer if staying in same country  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 986                                                0.0
# 987                                                0.0
# 988                                                NaN
# 989                                                NaN
# 990                                                NaN
#
#      Number of vacation days  Number of home office days per month  \
# 0                       29.0                                   4.0
# 1                       22.0                                   4.0
# 2                       27.0                                   NaN
# 3                       24.0                                   NaN
# 4                       30.0                                   0.0
# ..                       ...                                   ...
# 986                     25.0                                   5.0
# 987                     27.0                                   5.0
# 988                     30.0                                   5.0
# 989                     26.0                                   6.0
# 990                     30.0                                   5.0
#
#      Main language at work  Company name   Company size         Company type  \
# 0                  English            NaN        50-100              Startup
# 1                  English            NaN         10-50              Product
# 2                  English            NaN         1000+              Startup
# 3                  English          Auto1      100-1000              Product
# 4                  English         Luxoft        50-100              Product
# ..                     ...            ...           ...                  ...
# 986                English            NaN         1000+              Product
# 987                English            ING         1000+                 Bank
# 988                English            SAP         1000+              Product
# 989                English            NaN         1000+              Product
# 990                Deutsch            NaN         1000+  Consulting / Agency
#
#     Сontract duration Company business sector   0
# 0           unlimited                 Tourism NaN
# 1           unlimited   Scientific Activities NaN
# 2           unlimited                     NaN NaN
# 3           unlimited               Transport NaN
# 4           unlimited              Automotive NaN
# ..                ...                     ...  ..
# 986         unlimited                 Telecom NaN
# 987         unlimited     Finance / Insurance NaN
# 988         unlimited                Сommerce NaN
# 989  more than 1 year                  Health NaN
# 990         unlimited               Transport NaN
#
# [991 rows x 23 columns]>

# %%
df2.isnull().sum()
# Out:
# Zeitstempel                                                                                               0
# Age                                                                                                     109
# Gender                                                                                                    0
# City                                                                                                      0
# Seniority level                                                                                          15
# Position (without seniority)                                                                              1
# Years of experience                                                                                       0
# Your main technology / programming language                                                              14
# Yearly brutto salary (without bonus and stocks)                                                           1
# Yearly bonus                                                                                            461
# Yearly stocks                                                                                           788
# Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country    388
# Yearly bonus one year ago. Only answer if staying in same country                                       734
# Yearly stocks one year ago. Only answer if staying in same country                                      852
# Number of vacation days                                                                                  60
# Number of home office days per month                                                                    352
# Main language at work                                                                                     5
# Company name                                                                                            734
# Company size                                                                                             14
# Company type                                                                                             31
# Сontract duration                                                                                        29
# Company business sector                                                                                 145
# 0                                                                                                       991
# dtype: int64

# %%
missiing=df2.isnull().sum()*100/len(df2)
df2_missing_df={'% missing': missiing,
                'columns': df2.columns}
df2_missing_df
# Out:
# {'% missing': Zeitstempel                                                                                               0.000000
#  Age                                                                                                      10.998991
#  Gender                                                                                                    0.000000
#  City                                                                                                      0.000000
#  Seniority level                                                                                           1.513623
#  Position (without seniority)                                                                              0.100908
#  Years of experience                                                                                       0.000000
#  Your main technology / programming language                                                               1.412714
#  Yearly brutto salary (without bonus and stocks)                                                           0.100908
#  Yearly bonus                                                                                             46.518668
#  Yearly stocks                                                                                            79.515641
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country     39.152371
#  Yearly bonus one year ago. Only answer if staying in same country                                        74.066599
#  Yearly stocks one year ago. Only answer if staying in same country                                       85.973764
#  Number of vacation days                                                                                   6.054490
#  Number of home office days per month                                                                     35.519677
#  Main language at work                                                                                     0.504541
#  Company name                                                                                             74.066599
#  Company size                                                                                              1.412714
#  Company type                                                                                              3.128153
#  Сontract duration                                                                                         2.926337
#  Company business sector                                                                                  14.631685
#  0                                                                                                       100.000000
#  dtype: float64,
#  'columns': Index(['Zeitstempel', 'Age', 'Gender', 'City', 'Seniority level',
#         'Position (without seniority)', 'Years of experience',
#         'Your main technology / programming language',
#         'Yearly brutto salary (without bonus and stocks)', 'Yearly bonus',
#         'Yearly stocks',
#         'Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country',
#         'Yearly bonus one year ago. Only answer if staying in same country',
#         'Yearly stocks one year ago. Only answer if staying in same country',
#         'Number of vacation days', 'Number of home office days per month',
#         'Main language at work', 'Company name ', 'Company size',
#         'Company type', 'Сontract duration', 'Company business sector', '0'],
#        dtype='object')}
