# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("~/downloads/finance.csv")

# %%
df.tail(100)
# Out:
#           id country     year Has a Bank account Type of Location  \
# 22803  23416  Uganda  00:00.0                 No            Rural
# 22804  23417  Uganda  00:00.0                 No            Urban
# 22805  23418  Uganda  00:00.0                 No            Rural
# 22806  23419  Uganda  00:00.0                 No            Urban
# 22807  23420  Uganda  00:00.0                 No            Rural
# ...      ...     ...      ...                ...              ...
# 22898  23518  Uganda  00:00.0                 No            Rural
# 22899  23519  Uganda  00:00.0                 No            Rural
# 22900  23520  Uganda  00:00.0                 No            Rural
# 22901  23521  Uganda  00:00.0                 No            Rural
# 22902  23522  Uganda  00:00.0                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 22803                No             4.0            23.0                 Male
# ...

# %%
df.shape, df.size
# Out:
# ((22903, 13), 297739)

# %%
df.describe()
# Out:
#                  id  household_size  Respondent Age
# count  22903.000000    22876.000000    22870.000000
# mean   11744.106755        3.573396       38.345081
# std     6750.215443        2.079783       15.804023
# min        0.000000        0.000000       16.000000
# 25%     5919.500000        2.000000       26.000000
# 50%    11763.000000        3.000000       35.000000
# 75%    17575.500000        5.000000       48.000000
# max    23522.000000        9.000000       83.000000

# %%
x=(df["Respondent Age"])
plt.hist(x,100,density=True, facecolor="green")
plt.show()

# %%
df.info
# Out:
# <bound method DataFrame.info of           id country     year Has a Bank account Type of Location  \
# 0          0   Kenya  00:00.0                Yes            Rural
# 1          1   Kenya  00:00.0                 No            Rural
# 2          2   Kenya  00:00.0                Yes            Urban
# 3          3   Kenya  00:00.0                 No            Rural
# 4          4   Kenya  00:00.0                 No            Urban
# ...      ...     ...      ...                ...              ...
# 22898  23518  Uganda  00:00.0                 No            Rural
# 22899  23519  Uganda  00:00.0                 No            Rural
# 22900  23520  Uganda  00:00.0                 No            Rural
# 22901  23521  Uganda  00:00.0                 No            Rural
# 22902  23522  Uganda  00:00.0                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'country', 'year', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'The relathip with head', 'marital_status',
#        'Level of Education', 'Type of Job'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                          int64
# country                    object
# year                       object
# Has a Bank account         object
# Type of Location           object
# Cell Phone Access          object
# household_size            float64
# Respondent Age            float64
# gender_of_respondent       object
# The relathip with head     object
# marital_status             object
# Level of Education         object
# Type of Job                object
# dtype: object

# %%
df.isnull().any()
# Out:
# id                        False
# country                    True
# year                      False
# Has a Bank account         True
# Type of Location           True
# Cell Phone Access          True
# household_size             True
# Respondent Age             True
# gender_of_respondent       True
# The relathip with head     True
# marital_status             True
# Level of Education         True
# Type of Job                True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                         0
# country                   14
# year                       0
# Has a Bank account        36
# Type of Location          15
# Cell Phone Access         11
# household_size            27
# Respondent Age            33
# gender_of_respondent      33
# The relathip with head     4
# marital_status            31
# Level of Education        29
# Type of Job               30
# dtype: int64

# %%
missing=(df.isnull().sum()*100/len(df))
missing_df=pd.DataFrame({'Percentage missing': missing})
missing_df
# Out:
#                         Percentage missing
# id                                0.000000
# country                           0.061127
# year                              0.000000
# Has a Bank account                0.157185
# Type of Location                  0.065494
# Cell Phone Access                 0.048029
# household_size                    0.117888
# Respondent Age                    0.144086
# gender_of_respondent              0.144086
# The relathip with head            0.017465
# marital_status                    0.135353
# Level of Education                0.126621
# Type of Job                       0.130987

# %%
df['Level of Education'].unique
# Out:
# <bound method Series.unique of 0                    Secondary education
# 1                    No formal education
# 2        Vocational/Specialised training
# 3                      Primary education
# 4                      Primary education
#                       ...
# 22898                  Primary education
# 22899                No formal education
# 22900                Secondary education
# 22901                  Primary education
# 22902                Secondary education
# Name: Level of Education, Length: 22903, dtype: object>

# %%
df['Level of Education'].value_counts()
# Out:
# Primary education                  12527
# No formal education                 4270
# Secondary education                 4113
# Tertiary education                  1146
# Vocational/Specialised training      787
# 6                                     25
# Other/Dont know/RTA                    6
# Name: Level of Education, dtype: int64

# %%
df['Level of Education'].value_counts().plot(kind='bar')
plt.xlabel("Level of Education")
plt.ylabel("Counts");

# %%
df['marital_status'].value_counts().plot(kind='bar')
plt.xlabel("Marital Status")
plt.ylabel("Head Count");

# %%
df['Type of Job'].value_counts().plot(kind='bar')
plt.xlabel("Type of Job")
plt.ylabel("Head Count");

# %%
df.pivot_table('Respondent Age',columns='gender_of_respondent', index='country')
# Out:
# gender_of_respondent     Female       Male
# country
# Kenya                 38.671318  39.457600
# Rwanda                39.534093  38.024566
# Tanzania              37.036183  39.171688
# Uganda                34.508648  36.227481

# %%
import seaborn as sns
sns.set();

# %%
with sns.axes_style("white"):
    sns.violinplot(x='country',y='Respondent Age', hue='gender_of_respondent', data=df,
                   palette=['pink','steelblue'])

# %%
with sns.axes_style("white"):
    sns.jointplot(x='country',y='Respondent Age', data=df)

# %%
with sns.axes_style("white"):
    sns.displot(data=df, x='Respondent Age')

# %%
with sns.axes_style("white"):
    sns.histplot(data=df,x='household_size',y='Respondent Age', hue='gender_of_respondent')

# %%
df.
