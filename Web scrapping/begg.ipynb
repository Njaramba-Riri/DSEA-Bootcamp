# %%
# Out:
#   Cell In [4], line 1
#     uvicorn main:app --reload
#             ^
# SyntaxError: invalid syntax

# %%
# %pip install "uvicorn[standard]"
# Out:
# Requirement already satisfied: uvicorn[standard] in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (0.20.0)
# Requirement already satisfied: h11>=0.8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]) (0.14.0)
# Requirement already satisfied: click>=7.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]) (8.1.3)
# Requirement already satisfied: colorama>=0.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]) (0.4.6)
# Collecting websockets>=10.4
#   Downloading websockets-10.4-cp39-cp39-win_amd64.whl (101 kB)
#      ------------------------------------ 101.4/101.4 kB 126.8 kB/s eta 0:00:00
# Collecting httptools>=0.5.0
#   Downloading httptools-0.5.0-cp39-cp39-win_amd64.whl (145 kB)
#      ------------------------------------ 145.1/145.1 kB 107.9 kB/s eta 0:00:00
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.18.1-cp37-abi3-win_amd64.whl (264 kB)
#      -------------------------------------- 264.0/264.0 kB 1.3 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: anyio>=3.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from watchfiles>=0.13->uvicorn[standard]) (3.6.2)
# Requirement already satisfied: idna>=2.8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]) (1.3.0)
# Installing collected packages: websockets, pyyaml, python-dotenv, httptools, watchfiles
# Successfully installed httptools-0.5.0 python-dotenv-1.0.0 pyyaml-6.0 watchfiles-0.18.1 websockets-10.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script watchfiles.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install fastAPI
# Out:
# Collecting fastAPI
#   Downloading fastapi-0.92.0-py3-none-any.whl (56 kB)
#      -------------------------------------- 56.2/56.2 kB 730.1 kB/s eta 0:00:00
# Collecting starlette<0.26.0,>=0.25.0
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      --------------------------------------- 66.4/66.4 kB 43.8 kB/s eta 0:00:00
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.10.5-cp39-cp39-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 901.9 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastAPI) (4.4.0)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      -------------------------------------- 80.6/80.6 kB 376.4 kB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.26.0,>=0.25.0->fastAPI) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.26.0,>=0.25.0->fastAPI) (3.4)
# Installing collected packages: pydantic, anyio, starlette, fastAPI
# Successfully installed anyio-3.6.2 fastAPI-0.92.0 pydantic-1.10.5 starlette-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://jumia.co.ke/'

# %%
contents=requests.get(url)

# %%
Soup=BeautifulSoup(contents.content )

print(Soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies &amp; More
#   </title>
#   <meta content="product" property="og:type"/>
#   <meta content="Jumia Kenya" property="og:site_name"/>
#   <meta content="Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies &amp; More" property="og:title"/>
#   <meta content="Jumia Kenya the #1 Online Store in Kenya ✓ Buy Phones, Electronics, Appliances, Groceries, Cleaning Supplies, Home Essentials from Top Brands ✓ Best Prices in Kenya ✓ Online Shop You Can Trust ✓ Order Now and Enjoy Pay on Delivery! " property="og:description"/>
#   <meta content="/" property="og:url"/>
#   <meta content="https://ke.jumia.is/cms/icons/jumialogo-x-4.png" property="og:image"/>
#   <meta content="en_KE" property="og:locale"/>
#   <meta content="Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies &amp; More" name="title"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Jumia Kenya the #1 Online Store in Kenya ✓ Buy Phones, Electronics, Appliances, Groceries, Cleaning Supplies, Home Essentials from Top Brands ✓ Best Prices in Kenya ✓ Online Shop You Can Trust ✓ Order Now and Enjoy Pay on Delivery! " name="description"/>
#   <link href="android-app://com.jumia.android/JUMIA/KE?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.co.ke%2F" rel="alternate"/>
#   <link href="https://www.jumia.co.ke/" rel="canonical"/>
#   <link href="https://www.jumia.com.eg/" hreflang="en-eg" rel="alternate"/>
#   <link href="https://www.jumia.com.eg/ar/" hreflang="ar" rel="alternate"/>
#   <link href="https://www.jumia.ma/" hreflang="fr" rel="alternate"/>
#   <link href="https://www.jumia.ma/ar/" hreflang="ar-ma" rel="alternate"/>
#   <link href="https://www.jumia.dz/ar/" hreflang="ar-dz" rel="alternate"/>
#   <link href="https://www.jumia.co.ke/" hreflang="en-ke" rel="alternate"/>
#   <link href="https://www.jumia.ci/" hreflang="fr-ci" rel="alternate"/>
#   <link href="https://www.jumia.com.gh/" hreflang="en-gh" rel="alternate"/>
#   <link href="https://www.jumia.sn/" hreflang="fr-sn" rel="alternate"/>
#   <link href="https://www.jumia.dz/" hreflang="fr-dz" rel="alternate"/>
#   <link href="https://www.jumia.com.tn/" hreflang="fr-tn" rel="alternate"/>
#   <link href="https://www.jumia.ug/" hreflang="en-ug" rel="alternate"/>
#   <link href="https://www.jumia.com.ng/" hreflang="en" rel="alternate"/>
#   <meta content="2099414773624117" property="fb:app_id"/>
#   <meta content="395103207248808" property="fb:pages"/>
#   <meta content="n_VPq2qj81eefHQXQuWUQcpCjf22dILtzJ-5fqwv3cY" name="google-site-verification"/>
#   <meta content="18D4C7784A54CEB370A0B89D0634A096" name="msvalidate.01"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.jumia.co.ke/assets_he/css/main.52703e1f.css" rel="stylesheet"/>
#   <link href="https://www.jumia.co.ke/assets_he/favicon.87f00114.ico" rel="icon" sizes="any" type="image/ico"/>
#   <link href="https://www.jumia.co.ke/assets_he/favicon.adbd556a.svg" rel="icon" type="image/svg+xml"/>
#   <link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/>
#   <link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.facebook.com" rel="preconnect dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="preconnect dns-prefetch"/>
#   <link href="//static.criteo.net" rel="preconnect dns-prefetch"/>
#   <link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//creativecdn.com" rel="preconnect dns-prefetch"/>
#   <link href="https://ke.jumia.is" rel="dns-prefetch"/>
#  </head>
#  <body>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"200156797","agentToken":null,"applicationTime":103.321345,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFn5aDwdCRRVmLjUw","queueTime":0,"ttGuid":"c3d841d9ca40aaaf"}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"b76de0635f",applicationID:"200156797"};;(()=>{var e,t,r={9071:(e,t,r)=>{"use strict";r.d(t,{I:()=>n});var n=0,i=navigator.userAgent.match(/Firefox[\/\s](\d+\.\d+)/);i&&(n=+i[1])},6562:(e,t,r)=>{"use strict";r.d(t,{P_:()=>p,Mt:()=>v,C5:()=>d,DL:()=>y,OP:()=>N,lF:()=>B,Yu:()=>A,Dg:()=>h,CX:()=>f,GE:()=>w,sU:()=>M});var n={};r.r(n),r.d(n,{agent:()=>x,match:()=>j,version:()=>O});var i=r(6797),o=r(909),a=r(8610);class s{constructor(e,t){try{if(!e||"object"!=typeof e)return(0,a.Z)("New setting a Configurable requires an object as input");if(!t||"object"!=typeof t)return(0,a.Z)("Setting a Configurable requires a model to set its initial properties");Object.assign(this,t),Object.entries(e).forEach((e=>{let[t,r]=e;const n=(0,o.q)(t);n.length&&r&&"object"==typeof r&&n.forEach((e=>{e in r&&((0,a.Z)('"'.concat(e,'" is a protected attribute and can not be changed in feature ').concat(t,".  It will have no effect.")),delete r[e])})),this[t]=r}))}catch(e){(0,a.Z)("An error occured while setting a Configurable",e)}}}const c={beacon:i.ce.beacon,errorBeacon:i.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},u={};function d(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!u[e])throw new Error("Info for ".concat(e," was never set"));return u[e]}function f(e,t){if(!e)throw new Error("All info objects require an agent identifier!");u[e]=new s(t,c),(0,i.Qy)(e,u[e],"info")}const l={allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0,harvestTimeSeconds:10},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30},session_trace:{enabled:!0,harvestTimeSeconds:10},spa:{enabled:!0,harvestTimeSeconds:10}},g={};function p(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!g[e])throw new Error("Configuration for ".concat(e," was never set"));return g[e]}function h(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");g[e]=new s(t,l),(0,i.Qy)(e,g[e],"config")}function v(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=p(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const m={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},b={};function y(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!b[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return b[e]}function w(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");b[e]=new s(t,m),(0,i.Qy)(e,b[e],"loader_config")}const A=(0,i.mF)().o;var E=r(2053),x=null,O=null;if(navigator.userAgent){var T=navigator.userAgent,S=T.match(/Version\/(\S+)\s+Safari/);S&&-1===T.indexOf("Chrome")&&-1===T.indexOf("Chromium")&&(x="Safari",O=S[1])}function j(e,t){if(!x)return!1;if(e!==x)return!1;if(!t)return!0;if(!O)return!1;for(var r=O.split("."),n=t.split("."),i=0;i<n.length;i++ ...
#   </script>
#   <div id="jm">
#    <div class="banner" data-bnrid="101" data-end="2023-08-31T11:42:00+03:00" style="background:#b177da;">
#     <div class="row _no-go -phs">
#      <a class="col16 ar _1168-56" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Live_Generic_0223_STB.gif" data-id="home_STB_TW_GEN" data-name="STB_TW_GEN" data-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="/mlp-tech-week/?source=STB_TW_GEN">
#       <img alt="STB_TW_GEN" class="_ni" data-lazy="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Live_Generic_0223_STB.gif" src="..."/>
#      </a>
#     </div>
#    </div>
#    <div class="vb row -i-ctr -j-ctr _head -bg-gy05 -gy5">
#     <div class="col3 -df -j-start">
#      <a class="_link -df -i-ctr -or5 -m -fs12" href="https://www.jumia.co.ke/sp-market-place/" rel="noopener" target="_blank">
#       <svg class="ic -f-or5 -maxs" height="16" viewbox="0 0 24 24" width="16">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-services">
#        </use>
#       </svg>
#       Sell on Jumia
#      </a>
#     </div>
#     <div class="col10 -df -j-ctr -fs0">
#      <a class="vent-link" href="https://food.jumia.co.ke/" rel="nofollow noopener" target="_blank" title="Jumia Food">
#       <svg class="ic" height="24" viewbox="0 0 66 24" width="66">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#venture-food">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://www.jumia.co.ke/mlp-jumia-prime/" rel="nofollow noopener" target="_blank" title="Jumia Prime">
#       <svg class="ic" height="24" viewbox="0 0 77 24" width="77">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#venture-prime">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://food.jumia.co.ke/drinks/k0zt/jumia-party" rel="nofollow noopener" target="_blank" title="Jumia Party">
#      </a>
#      <a class="vent-link" href="https://pay.jumia.co.ke/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#       <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#venture-pay">
#        </use>
#       </svg>
#      </a>
#     </div>
#     <div class="col3 -df -j-end -wt -mla -gy5">
#     </div>
#    </div>
#    <header class="header">
#     <section class="row -i-ctr -fw-nw -pvm">
#      <div class="col3 -df -i-ctr">
#       <a class="-df -i-ctr -mra" href="/">
#        <svg aria-label="Jumia Kenya - Online Shopping for TVs, Electronics, Phones, Fashion &amp; more" class="ic" height="30" role="img" viewbox="0 0 172 30" width="134">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-shop-jumia.9f5451c7.svg#logo">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <form action="/catalog/" class="cola -df" data-track-onsubmit="search" id="search" method="get">
#       <div class="find">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#search">
#         </use>
#        </svg>
#        <input aria-label="Search" autocomplete="off" id="fi-q" name="q" placeholder="Search products, brands and categories" required="" type="text" value=""/>
#        <button aria-label="Reset" class="rst" type="button">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#close">
#          </use>
#         </svg>
#        </button>
#        <div class="sug">
#        </div>
#       </div>
#       <button class="btn _prim _md -mls -fsh0">
#        Search
#       </button>
#      </form>
#      <div class="col -df -j-bet -m -phn -i-ctr">
#       <div class="dpdw _pcent">
#        <input aria-controls="dpdw-login-box" aria-haspopup="true" aria-label="Account" class="tgl" id="dpdw-login" role="button" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-login">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#person">
#           </use>
#          </svg>
#         </span>
#         Account
#         <svg class="ic -mls -fsh0" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-login" class="box -r" id="dpdw-login-box" role="menu">
#         <div class="inbox">
#          <div class="-pam -hr-bb">
#           <a class="btn _prim -fw _md" href="/customer/account/login/?return=%2F">
#            Sign In
#           </a>
#          </div>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/account/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#person">
#            </use>
#           </svg>
#           My Account
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/order/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#orders">
#            </use>
#           </svg>
#           Orders
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/wishlist/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#favorite-border">
#            </use>
#           </svg>
#           Saved Items
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="dpdw _pcent">
#        <input aria-controls="dpdw-help-box" aria-haspopup="true" aria-label="Help" class="tgl" id="dpdw-help" role="button" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-help">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#help-outline">
#           </use>
#          </svg>
#         </span>
#         Help
#         <svg class="ic -mls -fsh0" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-help" class="box -r" id="dpdw-help-box" role="menu">
#         <div class="inbox">
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-help/">
#           Help Center
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-place-track-order/">
#           Place &amp; Track Order
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-cancel-order/">
#           Order Cancellation
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-returns-refunds/">
#           Returns &amp; Refunds
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-how-to-pay/">
#           Payment &amp; Jumia Account
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-contact/">
#           Contact us
#          </a>
#          <div class="-tac -hr _hx2 -fs0 -pam">
#           <button class="btn _prim _md _i -fw" data-btn-lc="" data-eventaction="open" data-eventcategory="LiveChat" data-track-onclick="">
#            <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#chat">
#             </use>
#            </svg>
#            <span>
#             Live Chat
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a class="-df -i-ctr -gy8 -hov-or5 -phs -fs16" href="/cart/">
#        <span class="-mrs -fs0" id="ci">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#shopping-cart">
#          </use>
#         </svg>
#        </span>
#        Cart
#       </a>
#      </div>
#     </section>
#    </header>
#    <article class="banner _pp" data-ppb-rev="v1.0">
#     <div class="ctt-w">
#      <p class="ctt">
#       This website uses cookies. For further information on how we use cookies you can read our
#       <a class="_more -fs12" href="/sp-privacy/" rel="noopener" target="_blank">
#        Privacy and Cookie notice
#       </a>
#      </p>
#      <button aria-label="Close" class="cls">
#       <span class="ic-bg -bg-wt">
#        <svg class="ic -maxs" height="16" viewbox="0 0 24 24" width="16">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#close">
#         </use>
#        </svg>
#       </span>
#      </button>
#     </div>
#    </article>
#    <main class="has-b2top">
#     <style>
#      @media(min-width:1200px){main{background:center 0 no-repeat url('https://ke.jumia.is/cms/2023/Techweek/Live/HP/Day02/Phones/KE_TW23_PhonesDay_0223_Takeover.jpg');}}main{background-color:#b177da;}
#     </style>
#     <div class="row -pvm">
#      <div class="col16 -df -j-bet -pbs">
#       <div class="flyout-w -fsh0 -fs0">
#        <div class="flyout" role="menu">
#         <a class="itm" href="https://www.jumia.co.ke/groceries/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-groceries">
#           </use>
#          </svg>
#          <span class="text">
#           Supermarket
#          </span>
#         </a>
#         <a class="itm" href="/health-beauty/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-beauty">
#           </use>
#          </svg>
#          <span class="text">
#           Health &amp; Beauty
#          </span>
#         </a>
#         <a class="itm" href="/home-office/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-appliance">
#           </use>
#          </svg>
#          <span class="text">
#           Home &amp; Office
#          </span>
#         </a>
#         <a class="itm" href="https://www.jumia.co.ke/home-office-appliances/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-appliance">
#           </use>
#          </svg>
#          <span class="text">
#           Appliances
#          </span>
#         </a>
#         <a class="itm" href="/phones-tablets/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-mobile">
#           </use>
#          </svg>
#          <span class="text">
#           Phones &amp; Tablets
#          </span>
#         </a>
#         <a class="itm" href="/computing/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-computing">
#           </use>
#          </svg>
#          <span class="text">
#           Computing
#          </span>
#         </a>
#         <a class="itm" href="https://www.jumia.co.ke/electronics/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-tv">
#           </use>
#          </svg>
#          <span class="text">
#           TVs &amp; Audio
#          </span>
#         </a>
#         <a class="itm" href="/category-fashion-by-jumia/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-fashion">
#           </use>
#          </svg>
#          <span class="text">
#           Fashion
#          </span>
#         </a>
#         <a class="itm" href="/video-games/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-games">
#           </use>
#          </svg>
#          <span class="text">
#           Gaming
#          </span>
#         </a>
#         <a class="itm" href="/baby-products/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-baby">
#           </use>
#          </svg>
#          <span class="text">
#           Baby Products
#          </span>
#         </a>
#         <a class="itm" href="/sporting-goods/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-fitness">
#           </use>
#          </svg>
#          <span class="text">
#           Sporting Goods
#          </span>
#         </a>
#         <a class="itm" role="menuitem" tabindex="0">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#cat-othercategories">
#           </use>
#          </svg>
#          <span class="text">
#           Other categories
#          </span>
#         </a>
#        </div>
#       </div>
#       <div class="sldr _img _main -rad4 -oh -fsh0 -mhm" data-track-onsliderview="eecPromo" id="sl-topblock">
#        <input checked="" class="sld" id="sl-topblock-sld-1" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Day02/Phones/KE_TW23_PhonesDay_Deals_0223_S.jpg" data-id="home_SX_TW_UND_PhonesDay" data-name="SX_TW_UND_PhonesDay" data-position="slider_1_1" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/smartphones/">
#         <img alt="Phones Day" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Day02/Phones/KE_TW23_PhonesDay_Deals_0223_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 6" class="lab" for="sl-topblock-sld-6">
#        </label>
#        <label aria-label="Go to slide 1" class="dot" for="sl-topblock-sld-1">
#        </label>
#        <input class="sld" id="sl-topblock-sld-2" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Live_Generic_Partners_0223_S_GIF.gif" data-id="home_SX_TW_GEN" data-name="SX_TW_GEN" data-position="slider_1_2" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/mlp-tech-week/">
#         <img alt="Tech Week" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Live_Generic_Partners_0223_S_GIF.gif" src="..."/>
#        </a>
#        <label aria-label="Go to slide 1" class="lab" for="sl-topblock-sld-1">
#        </label>
#        <label aria-label="Go to slide 2" class="dot" for="sl-topblock-sld-2">
#        </label>
#        <input class="sld" id="sl-topblock-sld-3" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Sliders/KE_TW23_Live_TVsDeals_0223_S_rvsd.jpg" data-id="home_SX_TW_ACD_TVs" data-name="SX_TW_ACD_TVs" data-position="slider_1_3" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/mlp-tech-week-h-movie-night/">
#         <img alt="TVs" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Sliders/KE_TW23_Live_TVsDeals_0223_S_rvsd.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 2" class="lab" for="sl-topblock-sld-2">
#        </label>
#        <label aria-label="Go to slide 3" class="dot" for="sl-topblock-sld-3">
#        </label>
#        <input class="sld" id="sl-topblock-sld-4" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2023/W08/WebsiteQC/KE_TW23_Live_Tecno_Deals_0223_S2_rvsd2_rvsd.jpg" data-id="home_SX_TW_ACD_Tecno" data-name="SX_TW_ACD_Tecno" data-position="slider_1_4" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/mlp-tecno-official-store/">
#         <img alt="Tecno" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2023/W08/WebsiteQC/KE_TW23_Live_Tecno_Deals_0223_S2_rvsd2_rvsd.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 3" class="lab" for="sl-topblock-sld-3">
#        </label>
#        <label aria-label="Go to slide 4" class="dot" for="sl-topblock-sld-4">
#        </label>
#        <input class="sld" id="sl-topblock-sld-5" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Sliders/KE_TW23_Live_AppliancesDeals_0223_S.jpg" data-id="home_SX_TW_ACD_Appliances" data-name="SX_TW_ACD_Appliances" data-position="slider_1_5" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/mlp-tech-week-h-home-appliances/">
#         <img alt="Appliances" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Sliders/KE_TW23_Live_AppliancesDeals_0223_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 4" class="lab" for="sl-topblock-sld-4">
#        </label>
#        <label aria-label="Go to slide 5" class="dot" for="sl-topblock-sld-5">
#        </label>
#        <input class="sld" id="sl-topblock-sld-6" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Sliders/KE_TW23_Live_GamersHaven_0223_S_rvsd.jpg" data-id="home_SX_TW_ACD_GamersHaven" data-name="SX_TW_ACD_GamersHaven" data-position="slider_1_6" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/mlp-tech-week-h-for-the-gamers/">
#         <img alt="Gamers Haven" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Sliders/KE_TW23_Live_GamersHaven_0223_S_rvsd.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 5" class="lab" for="sl-topblock-sld-5">
#        </label>
#        <label aria-label="Go to slide 6" class="dot" for="sl-topblock-sld-6">
#        </label>
#        <label aria-label="Go to slide 6" class="lab" for="sl-topblock-sld-6">
#        </label>
#        <label aria-label="Go to slide 1" class="lab" for="sl-topblock-sld-1">
#        </label>
#        <div class="left">
#         <svg class="ic -f-wt" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-left">
#          </use>
#         </svg>
#        </div>
#        <div class="right">
#         <svg class="ic -f-wt" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-right">
#          </use>
#         </svg>
#        </div>
#       </div>
#       <div class="-df -c-bet -fw-w -fg1 -m-dn -h-flyout -oh -fs0">
#        <div class="card -df -fw-w -c-spar -fg1 -phm -h-50p_-m -oh">
#         <a class="-df -i-ctr -oh -fw" data-creative="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/Webp.net-resizeimage-(1).png" data-id="home_HELP CENTER" data-name="HELP CENTER" data-position="topblock_top_1" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/sp-help/?source=HP_ICON">
#          <img alt="HELP CENTER" class="_ni -fsh0 -mrs" data-lazy="" data-src="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/Webp.net-resizeimage-(1).png" height="34" src="..." width="34"/>
#          <div class="-flupp -gy8 -oh">
#           <div class="-m -fs14 -elli">
#            HELP CENTER
#           </div>
#           <div class="-fs12 -elli">
#            Guide To Customer Care
#           </div>
#          </div>
#         </a>
#         <a class="-df -i-ctr -oh -fw" data-creative="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-return.png" data-id="home_EASY RETURN" data-name="EASY RETURN" data-position="topblock_top_2" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/sp-returns-refunds/?source=HP_Icon">
#          <img alt="EASY RETURN" class="_ni -fsh0 -mrs" data-lazy="" data-src="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-return.png" height="34" src="..." width="34"/>
#          <div class="-flupp -gy8 -oh">
#           <div class="-m -fs14 -elli">
#            EASY RETURN
#           </div>
#           <div class="-fs12 -elli">
#            Quick Refund
#           </div>
#          </div>
#         </a>
#         <a class="-df -i-ctr -oh -fw" data-creative="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-payment.png" data-id="home_SELL ON JUMIA" data-name="SELL ON JUMIA" data-position="topblock_top_3" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/sp-market-place/?source=HP_Icon">
#          <img alt="SELL ON JUMIA" class="_ni -fsh0 -mrs" data-lazy="" data-src="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-payment.png" height="34" src="..." width="34"/>
#          <div class="-flupp -gy8 -oh">
#           <div class="-m -fs14 -elli">
#            SELL ON JUMIA
#           </div>
#           <div class="-fs12 -elli">
#            Millions Of Visitors
#           </div>
#          </div>
#         </a>
#        </div>
#        <div class="-fw" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Live_Vlogging_0223_BF.gif" data-id="home_‎Tech Week" data-name="‎Tech Week" data-position="topblock_bottom" data-track-onclick="eecPromo" data-track-onview="eecPromo">
#         <a class="card ar _109-92 -oh -fs0 -h-50p_-m" href="https://www.jumia.co.ke/mlp-tech-week-h-for-content-creators/">
#          <img alt="‎Tech Week" data-lazy="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Live_Vlogging_0223_BF.gif" src="..."/>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="col16 -pvs">
#       <section class="card -oh _fw -rad4">
#        <div class="crs-w _main _thumb -fs0 _nav -tac _c-btn-on">
#         <div class="crs">
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Thumbnail_0223_TN.png" data-id="home_DTN_TW" data-name="DTN_TW" data-position="thumbnails_1_1" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-tech-week/">
#            <div class="ar _1-1">
#             <img alt="LIVE NOW" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/Techweek/Live/HP/Generics/KE_TW23_Thumbnail_0223_TN.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             LIVE NOW
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/TVs.png" data-id="home_DTN_Televisions" data-name="DTN_Televisions" data-position="thumbnails_1_2" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/televisions/">
#            <div class="ar _1-1">
#             <img alt="Televisions" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/TVs.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Televisions
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Phones.png" data-id="home_DTN_Smartphones" data-name="DTN_Smartphones" data-position="thumbnails_1_3" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/smartphones/">
#            <div class="ar _1-1">
#             <img alt="Phones" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Phones.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Phones
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Laptops.png" data-id="home_DTN_Computing" data-name="DTN_Computing" data-position="thumbnails_1_4" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/computing/">
#            <div class="ar _1-1">
#             <img alt="Computing" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Laptops.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Computing
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Speakers.png" data-id="home_DTN_SpeakerSystems" data-name="DTN_SpeakerSystems" data-position="thumbnails_1_5" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/home-theatre/">
#            <div class="ar _1-1">
#             <img alt="Speaker Systems" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Speakers.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Speaker Systems
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Blenders.png" data-id="home_DTN_Blenders" data-name="DTN_Blenders" data-position="thumbnails_1_6" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/blenders/">
#            <div class="ar _1-1">
#             <img alt="Blenders" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Blenders.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Blenders
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Cooktops.png" data-id="home_DTN_Cooktops" data-name="DTN_Cooktops" data-position="thumbnails_1_7" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/cooking-appliances-cook-top/">
#            <div class="ar _1-1">
#             <img alt="Cooktops" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Cooktops.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Cooktops
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W07/HP/Revised/FBJ-resized.png" data-id="home_DTN_FBJ" data-name="DTN_FBJ" data-position="thumbnails_1_8" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-fulfilled-by-jumia/">
#            <div class="ar _1-1">
#             <img alt="Top Deals" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W07/HP/Revised/FBJ-resized.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Top Deals
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Sneakers.png" data-id="home_DTN_Sneakers" data-name="DTN_Sneakers" data-position="thumbnails_1_9" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-sneakers/">
#            <div class="ar _1-1">
#             <img alt="Sneakers" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Sneakers.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Sneakers
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Home.png" data-id="home_DTN_Home" data-name="DTN_Home" data-position="thumbnails_1_10" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/home-office/">
#            <div class="ar _1-1">
#             <img alt="Home" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Home.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Home
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/MenClothing.png" data-id="home_DTN_MensFashion" data-name="DTN_MensFashion" data-position="thumbnails_1_11" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mens-fashion/">
#            <div class="ar _1-1">
#             <img alt="Men's Fashion" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/MenClothing.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Men's Fashion
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2023/W05/Thumbnails/Beauty.png" data-id="home_DTN_Beauty" data-name="DTN_Beauty" data-position="thumbnails_1_12" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-beauty-week/">
#            <div class="ar _1-1">
#             <img alt="Beauty" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2023/W05/Thumbnails/Beauty.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Beauty
#            </p>
#           </a>
#          </div>
#         </div>
#         <button class="c-btn _prev _dis" type="button">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-left">
#           </use>
#          </svg>
#         </button>
#         <button class="c-btn _next" type="button">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-right">
#           </use>
#          </svg>
#         </button>
#        </div>
#       </section>
#      </div>
#      <div class="reco _hid col16" data-list="lastViewed" data-reco-onview="lastViewed">
#       <div class="reco-w card -mvs">
#        <header class="-df -fw -pas -i-ctr -mh-48px">
#         <h2 class="-phs -fs20 -m -f1 -elli">
#          Last Viewed
#          <span class="-r" data-plc-subtitle="">
#          </span>
#         </h2>
#         <a class="-df -i-ctr -fsh0 -upp -m -lh-1 -pvxs -mla -or5" data-plc-href="">
#          See All
#          <svg class="ic -f-or5" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-right">
#           </use>
#          </svg>
#         </a>
#        </header>
#        <div data-plc="">
#        </div>
#       </div>
#      </div>
#      <div class="col16 -pvs">
#       <section class="card -oh _fw -rad4">
#        <header class="row _no-g -fw-nw -j-bet -i-ctr -phm -mh-48px" style="color:#FFFFFF;background:#e61601;">
#         <div class="cola -df -i-ctr -oh col5">
#          <svg class="ic -fsh0 -mrs" height="32" viewbox="0 0 24 24" width="32">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#flash-sales">
#           </use>
#          </svg>
#          <h2 class="-m -fs20 -elli">
#           Flash Sales
#          </h2>
#         </div>
#         <div class="col6 -mra -fs20 -tac">
#          Time Left:
#          <time class="-b -ws-p" data-cd="" datetime="2023-02-28T23:59:58+03:00">
#           01h : 22m : 22s
#          </time>
#         </div>
#         <div class="col -df -j-end -fsh0">
#          <a class="-df -i-ctr -upp -m -mls -pvxs" href="/flash-sales/">
#           See All
#           <svg class="ic" height="24" style="fill:#FFFFFF;" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#arrow-right">
#            </use>
#           </svg>
#          </a>
#         </div>
#        </header>
#        <div class="crs-w _main -phxs">
#         <div class="crs row _no-g -fw-nw _6cl-4cm -pvxs">
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="NIVEA" data-category="Health &amp; Beauty/Beauty &amp; Personal Care/Personal Care/Skin Care/Face/Cleansers" data-dimension23="" data-dimension26="" data-dimension27="" data-dimension28="1" data-dimension37="0" data-dimension43="BF22|CFS|COL_216|COL_224|CP_MT117|CP_UN5|CP_UN9|CP_UN94|FDY2020|JMALL|TBOOST|XMAS22|XMAS22_01" data-dimension44="0" data-id="NI534ST01U2JENAFAMZ" data-list="flashsale_1" data-name="Perfect &amp; Radiant Even Tone Day And Night Cream For Women - 50ml" data-position="1" data-price="7.68" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/nivea-perfect-radiant-even-tone-day-and-night-cream-for-women-50ml-68528030.html">
#             <img alt="NIVEA Perfect &amp; Radiant Even Tone Day And Night Cream For Women - 50ml" class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/03/082586/1.jpg?3405" height="185" src="..." width="185"/>
#             <div class="name">
#              NIVEA Perfect &amp; Radiant Even Tone Day And Night Cream For Women - 50ml
#             </div>
#             <div class="prc" data-oprc="KSh 1,290">
#              KSh 1,032
#             </div>
#             <div class="bdg _dsct">
#              20%
#             </div>
#             <div class="stk">
#              67 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f68b1e 100%,#c7c7cd 100%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="TCL" data-category="Electronics/Television &amp; Video/Televisions/Smart TVs" data-dimension23="124985" data-dimension26="" data-dimension27="" data-dimension28="1" data-dimension37="0" data-dimension43="CFS" data-dimension44="0" data-id="TC187EA2QVGABNAFAMZ" data-list="flashsale_1" data-name="43S68A 43'' Smart Android TVFrameless Full HD LED TV" data-position="2" data-price="203.93" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/tcl-43s68a-43-smart-android-tvframeless-full-hd-led-tv-111896066.html">
#             <img alt="TCL 43S68A 43'' Smart Android TVFrameless Full HD LED TV" class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/66/0698111/1.jpg?0725" height="185" src="..." width="185"/>
#             <div class="name">
#              TCL 43S68A 43'' Smart Android TVFrameless Full HD LED TV
#             </div>
#             <div class="prc" data-oprc="KSh 34,999">
#              KSh 27,399
#             </div>
#             <div class="bdg _dsct">
#              22%
#             </div>
#             <div class="stk">
#              271 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f68b1e 54.2%,#c7c7cd 54.2%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Skyworth" data-category="Electronics/Television &amp; Video/Televisions/Smart TVs" data-dimension23="111857" data-dimension26="" data-dimension27="" data-dimension28="1" data-dimension37="0" data-dimension43="CFS" data-dimension44="0" data-id="SK493EA06FGSGNAFAMZ" data-list="flashsale_1" data-name='43" 43E3A  FULL HD Frameless Smart Android TV - 43"' data-position="3" data-price="186.07" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/skyworth-43-43e3a-full-hd-frameless-smart-android-tv-43-69299701.html">
#             <img alt='Skyworth 43" 43E3A  FULL HD Frameless Smart Android TV - 43"' class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/10/799296/1.jpg?2616" height="185" src="..." width="185"/>
#             <div class="name">
#              Skyworth 43" 43E3A  FULL HD Frameless Smart Android TV - 43"
#             </div>
#             <div class="prc" data-oprc="KSh 44,999">
#              KSh 24,999
#             </div>
#             <div class="bdg _dsct">
#              44%
#             </div>
#             <div class="stk">
#              100 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f68b1e 100%,#c7c7cd 100%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Vitron" data-category="Electronics/Television &amp; Video/Televisions/Smart TVs" data-dimension23="105043" data-dimension26="" data-dimension27="" data-dimension28="1" data-dimension37="0" data-dimension43="BF22|CFS|COL_226|COL_317|CP_MT31|CP_UN10|CP_UN2|CP_UN3|CP_UN9|JMALL|MLP2|TBOOST|TW23|TW23_05|XMAS22|XMAS22_02|XMAS22_03|XMAS22_06|XMAS22_07" data-dimension44="0" data-id="VI505EA12D1VUNAFAMZ" data-list="flashsale_1" data-name='4368FS 43" Full HD Smart Android TV Netflix Youtube / 4388FS' data-position="4" data-price="148.85" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vitron-4368fs-43-full-hd-smart-android-tv-netflix-youtube-4388fs-87343446.html">
#             <img alt='Vitron 4368FS 43" Full HD Smart Android TV Netflix Youtube / 4388FS' class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/64/434378/1.jpg?0797" height="185" src="..." width="185"/>
#             <div class="name">
#              Vitron 4368FS 43" Full HD Smart Android TV Netflix Youtube / 4388FS
#             </div>
#             <div class="prc" data-oprc="KSh 26,999">
#              KSh 19,999
#             </div>
#             <div class="bdg _dsct">
#              26%
#             </div>
#             <div class="stk">
#              264 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f68b1e 63.30935251798561%,#c7c7cd 63.30935251798561%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Infinix" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="15899" data-dimension26="" data-dimension27="" data-dimension28="1" data-dimension37="0" data-dimension43="TBOOST" data-dimension44="0" data-id="IN213MP0OKT2QNAFAMZ" data-list="flashsale_1" data-name='Hot 12i, 6.6", 64GB + 4GB RAM (Dual SIM), 5000mAh, 4G, Racing Black' data-position="5" data-price="92.28" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/infinix-hot-12i-6.6-64gb-4gb-ram-dual-sim-5000mah-4g-racing-black-68518214.html">
# ...
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/terms-and-conditions/">
#          Terms and Conditions
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/privacy/">
#          Privacy Notice
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/sp-cookie-notice/">
#          Cookies Notice
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/sp-ups/">
#          UPS - Jumia International Shipping
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/flash-sales/">
#          Flash Sales
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/mlp-tech-week/">
#          Tech Week 23
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col4 -df -d-co -pvs">
#       <span class="f-t -pbm">
#        MAKE MONEY WITH JUMIA
#       </span>
#       <ul class="-lsn">
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/market-place/">
#          Sell on Jumia
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/jforce/">
#          Become a Sales Consultant
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://jumia_form.formstack.com/forms/3pl_interest_registration_en">
#          Become a Logistics Service Partner
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://forms.gle/WmYEPeQJbqgQD3Da8">
#          Jumia City Partner Program
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col4 row -c-start -pvs">
#       <span class="f-t col16 -pbm">
#        JUMIA INTERNATIONAL
#       </span>
#       <ul class="col5 -df -d-co -lsn">
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.dz/">
#          Algeria
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.ci/">
#          Ivory Coast
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.eg/">
#          Egypt
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.gh/">
#          Ghana
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.ma/">
#          Morocco
#         </a>
#        </li>
#       </ul>
#       <ul class="col5 -df -d-co -lsn">
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.ng/">
#          Nigeria
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.sn/">
#          Senegal
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.tn/">
#          Tunisia
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.ug/">
#          Uganda
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.zando.co.za/">
#          Zando
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="row -pbl">
#      <div class="col4 row">
#       <div class="f-t col16 -pbm">
#        JOIN US ON
#       </div>
#       <div class="col16 -phn -fs0">
#        <a class="ic-link -pas" href="https://www.facebook.com/JumiaKenya" rel="noopener" target="_blank" title="Facebook Jumia Kenya">
#         <svg class="ic" height="26" viewbox="0 0 24 24" width="26">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#soc-facebook">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.instagram.com/jumiakenya/" rel="noopener" target="_blank" title="Instagram Jumia Kenya">
#         <svg class="ic" height="26" viewbox="0 0 24 24" width="26">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#soc-instagram">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://twitter.com/JumiaKenya" rel="noopener" target="_blank" title="Twitter Jumia Kenya">
#        </a>
#        <a class="ic-link -pas" href="https://www.youtube.com/user/KenyaJumia" rel="noopener" target="_blank" title="YouTube Jumia Kenya">
#         <svg class="ic" height="26" viewbox="0 0 24 24" width="26">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#soc-youtube">
#          </use>
#         </svg>
#        </a>
#       </div>
#      </div>
#      <div class="col12 row">
#       <div class="f-t col16 -pbm">
#        PAYMENT METHODS
#       </div>
#       <div class="col16 -phn -df -fw-w">
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/payment/" title="Payment on delivery">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#pay-cashondelivery">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/payment/" title="Visa">
#         <svg class="ic" height="24" viewbox="0 0 31 24" width="31">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#pay-visa">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/payment/" title="Mastercard">
#         <svg class="ic" height="24" viewbox="0 0 36 24" width="36">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#pay-mastercard">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/jumiapay/" title="Jumia Pay">
#         <svg class="ic" height="24" viewbox="0 0 85 24" width="85">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#pay-jumiapay">
#          </use>
#         </svg>
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="row -pbl">
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/14-hands/">
#         14 Hands
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/adidas/">
#         Adidas
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/amtec/">
#         Amtec
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/apple/">
#         Apple
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/brand-asus/">
#         Asus
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/dell/">
#         DELL
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/garnier/">
#         Garnier
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/haier/">
#         Haier
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/hisense/">
#         Hisense
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/hp/">
#         HP
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/huawei/">
#         Huawei
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/infinix/">
#         Infinix
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/itel/">
#         Itel
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/lenovo/">
#         Lenovo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/lg/">
#         LG
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/nike/">
#         Nike
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nivea/">
#         NIVEA
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nokia_1/">
#         Nokia
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nunix/">
#         Nunix
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/oppo/">
#         Oppo
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/panasonic/">
#         Panasonic
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/ramtons/">
#         Ramtons
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/realme/">
#         Realme
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/samsung/">
#         Samsung
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/sandisk/">
#         Sandisk
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/skyworth/">
#         Skyworth
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/solarmax/">
#         Solarmax
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/sony/">
#         Sony
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/sunnypex/">
#         Sunnypex
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/syinix/">
#         Syinix
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/tagwood/">
#         TAGWOOD
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/tcl/">
#         TCL
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/tecno/">
#         Tecno
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/ulefone/">
#         Ulefone
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/umidigi/">
#         UMIDIGI
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/vision-plus/">
#         Vision Plus
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/vitron/">
#         Vitron
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/vivo/">
#         Vivo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/xiaomi/">
#         XIAOMI
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="vb row -i-ctr -j-ctr _foot _gy7 -hr -gy3 -mtl">
#      <div class="col3 -df -j-start">
#      </div>
#      <div class="col10 -df -j-ctr -fs0">
#       <a class="vent-link" href="https://www.jumia.co.ke/mlp-jumia-prime/" rel="nofollow noopener" target="_blank" title="Jumia Prime">
#        <svg class="ic" height="24" viewbox="0 0 77 24" width="77">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#venture-prime">
#         </use>
#        </svg>
#       </a>
#       <a class="vent-link" href="https://food.jumia.co.ke/drinks/k0zt/jumia-party" rel="nofollow noopener" target="_blank" title="Jumia Party">
#       </a>
#       <a class="vent-link" href="https://pay.jumia.co.ke/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#        <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg#venture-pay">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <div class="col3 -df -j-end -wt -mla">
#      </div>
#     </div>
#    </footer>
#    <div id="pop">
#     <div aria-hidden="false" aria-label="newsletter_popup_close-cta" aria-modal="true" class="popup _open _l" data-pop="" data-pop-id="newsletter" role="dialog">
#      <section aria-labelledby="pop-ttl" class="cw">
#       <button aria-label="newsletter_popup_close-cta" class="cls">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#close">
#         </use>
#        </svg>
#       </button>
#       <h2 class="ttl -vh-sr" id="pop-ttl">
#        Welcome to Jumia!
#       </h2>
#       <div class="cont _nl">
#        <div class="-df">
#         <div class="-fsh0" style="width:265px;background:url('https://ke.jumia.is/cms/2021/W15/CP/Banners/KE_Cross_0421_PU.jpg') top/cover no-repeat;">
#         </div>
#         <div class="-pvxl -phl -tac -fw">
#          <h2 class="-fs29 -phxl">
#           Welcome to Jumia!
#          </h2>
#          <div class="-ptl -phs">
#           <p class="-fs16 -m -pbxs">
#            Subscribe to our newsletter
#           </p>
#           and be the first one to know about our amazing deals
#          </div>
#          <form action="/newsletter/subscription/default/" class="-ptm -tal" data-eventaction="Subscribed" data-eventcategory="Newsletter Popup" data-track-onnlsuccess="" id="nl-pop-f" method="post">
#           <div class="fi-w -mhs _ic">
#            <input aria-label="E-mail" class="fi" id="fi-nl-pop-email" name="email" placeholder="Enter E-mail Address" required="" type="email" value=""/>
#            <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg#email">
#             </use>
#            </svg>
#           </div>
#           <div class="-df -ptxs -phxs">
#            <button class="-mhxs btn _prim _md -fw" name="gender" value="male">
#             Male
#            </button>
#            <button class="-mhxs btn _prim _md -fw" name="gender" value="female">
#             Female
#            </button>
#           </div>
#           <input name="csrfToken" type="hidden" value="544ce83c7ea6e2de3bf1f242a335a127"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <script>
#    var dataLayer=[{"countryCode":"KE","language":"en","platform":"desktop","url":"/","pageType":"home","pageKey":"home","pageTitle":"Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies & More","abTests":"Home:A#CLP:A#Cart:E#SponProdCat:A#NewCkt:A#NewCktAnd:A#NewCktiOS:A","joinedPageType":"home"}];(function(w,d,s,l,i,f){function go(){w[l]=w[l]||[];w[l].push({"gtm.start":new Date().getTime(),event:"gtm.js"});f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!="dataLayer"?"&l="+l:"";j.async=true;j.src="//www.googletagmanager.com/gtm.js?id="+i+dl;j.addEventListener('load',function(){dataLayer.push({event:'pageView'});(function(){setTimeout((function(){window.dataLayer.push({event:"pageViewLvl2"}),setTimeout((function(){window.dataLayer.push({event:"pageViewLvl3"})}),500)}),500)})()});f.parentNode.insertBefore(j,f);}w.addEventListener("load",go,false);})(window,document,'script','dataLayer','GTM-KS6DC65');
#   </script>
#   <script>
#    window.__STORE__={"view":"Home","activeLanguage":"en","countryCode":"KE","languages":{"en":{"text":"English","default":true}},"svgFallback":false,"tracking":{"gtm":{"key":"GTM-KS6DC65","url":"/","pageType":"home","pageKey":"home"}},"csrfToken":"544ce83c7ea6e2de3bf1f242a335a127","user":{"id":""},"sprites":{"icons":"https://www.jumia.co.ke/assets_he/images/i-icons.5fc0e713.svg","global":"https://www.jumia.co.ke/assets_he/images/i-global.23fe686b.svg","shop":"https://www.jumia.co.ke/assets_he/images/i-jumia.svg"},"liveChat":{"loadingText":"Live Chat is loading...","botImg":"https://www.jumia.co.ke/assets_he/images/bot.5beef7d8.svg"},"timeLabels":{"w":"w","d":"d","h":"h","m":"m","s":"s"},"htmlErrors":{"valueMissing":"Required field","typeMismatch":"Invalid Information","patternMismatch":"Invalid Information"},"popups":{"newsletter":{"data":{"title":"Welcome to Jumia!","closeCTA":"newsletter_popup_close-cta"},"trackingData":{"viewPopup":{"type":"Newsletter"},"closePopup":{"type":"Newsletter"}},"template":"Default","shouldOpen":true,"size":"L","hideTitle":true}}};
#   </script>
#   <script crossorigin="" src="https://www.jumia.co.ke/assets_he/js/common.d8a646a3.js" type="module">
#   </script>
#   <script crossorigin="" src="https://www.jumia.co.ke/assets_he/js/pages/home/index.c1b70a14.js" type="module">
#   </script>
#   <script nomodule="" src="https://www.jumia.co.ke/assets_he/js/common.es5.7a8ee2db.js">
#   </script>
#   <script nomodule="" src="https://www.jumia.co.ke/assets_he/js/pages/home/index.es5.41b1bef9.js">
#   </script>
#  </body>
# </html>
