# %% [markdown]
# Scrapping is technically a process of extracting data from websites

# %%
#import the necessary libraries
import requests
from bs4 import BeautifulSoup

# %%
#use the requests library to retrieve the html content of the website
url='https://www.imdb.com/chart/top'
response=requests.get(url)
html_content=response.content

# %%
#use the beatifulsoup library to parse the HTML content and extract the data yoyu need. In this case, it's title,year and the movie rating
soup=BeautifulSoup(html_content,'html.parser')
movies=[]

for row in soup.select('table.chart tbody tr'):
    title=row.select_one('.titleColumn a').text
    year=row.select_one('.titleColumn span.secondaryInfo').text
    rating=row.select_one('.imbdRating strong')
    movies.append((title,year,rating))

# %%
#print the list now
for movie in movies:
    print(movie)
# Out:
# ('The Shawshank Redemption', '(1994)', None)
# ('The Godfather', '(1972)', None)
# ('The Dark Knight', '(2008)', None)
# ('The Godfather Part II', '(1974)', None)
# ('12 Angry Men', '(1957)', None)
# ("Schindler's List", '(1993)', None)
# ('The Lord of the Rings: The Return of the King', '(2003)', None)
# ('Pulp Fiction', '(1994)', None)
# ('The Lord of the Rings: The Fellowship of the Ring', '(2001)', None)
# ('Il buono, il brutto, il cattivo', '(1966)', None)
# ('Forrest Gump', '(1994)', None)
# ('Fight Club', '(1999)', None)
# ('The Lord of the Rings: The Two Towers', '(2002)', None)
# ('Inception', '(2010)', None)
# ('The Empire Strikes Back', '(1980)', None)
# ('The Matrix', '(1999)', None)
# ('GoodFellas', '(1990)', None)
# ("One Flew Over the Cuckoo's Nest", '(1975)', None)
# ('Se7en', '(1995)', None)
# ('Shichinin no samurai', '(1954)', None)
# ("It's a Wonderful Life", '(1946)', None)
# ('The Silence of the Lambs', '(1991)', None)
# ('Cidade de Deus', '(2002)', None)
# ('Saving Private Ryan', '(1998)', None)
# ('Interstellar', '(2014)', None)
# ('La vita è bella', '(1997)', None)
# ('The Green Mile', '(1999)', None)
# ('Star Wars', '(1977)', None)
# ('Terminator 2: Judgment Day', '(1991)', None)
# ('Back to the Future', '(1985)', None)
# ('Sen to Chihiro no kamikakushi', '(2001)', None)
# ('The Pianist', '(2002)', None)
# ('Psycho', '(1960)', None)
# ('Gisaengchung', '(2019)', None)
# ('Léon', '(1994)', None)
# ('The Lion King', '(1994)', None)
# ('Gladiator', '(2000)', None)
# ('American History X', '(1998)', None)
# ('The Departed', '(2006)', None)
# ('The Usual Suspects', '(1995)', None)
# ('The Prestige', '(2006)', None)
# ('Whiplash', '(2014)', None)
# ('Casablanca', '(1942)', None)
# ('Seppuku', '(1962)', None)
# ('Hotaru no haka', '(1988)', None)
# ('The Intouchables', '(2011)', None)
# ('Modern Times', '(1936)', None)
# ('Once Upon a Time in the West', '(1968)', None)
# ('Rear Window', '(1954)', None)
# ('Nuovo Cinema Paradiso', '(1988)', None)
# ('Alien', '(1979)', None)
# ('City Lights', '(1931)', None)
# ('Apocalypse Now', '(1979)', None)
# ('Memento', '(2000)', None)
# ('Django Unchained', '(2012)', None)
# ('Raiders of the Lost Ark', '(1981)', None)
# ('WALL·E', '(2008)', None)
# ('The Lives of Others', '(2006)', None)
# ('Sunset Blvd.', '(1950)', None)
# ('Paths of Glory', '(1957)', None)
# ('The Shining', '(1980)', None)
# ('The Great Dictator', '(1940)', None)
# ('Avengers: Infinity War', '(2018)', None)
# ('Witness for the Prosecution', '(1957)', None)
# ('Aliens', '(1986)', None)
# ('Spider-Man: Into the Spider-Verse', '(2018)', None)
# ('American Beauty', '(1999)', None)
# ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', '(1964)', None)
# ('The Dark Knight Rises', '(2012)', None)
# ('Oldeuboi', '(2003)', None)
# ('Inglourious Basterds', '(2009)', None)
# ('Amadeus', '(1984)', None)
# ('Coco', '(2017)', None)
# ('Toy Story', '(1995)', None)
# ('Joker', '(2019)', None)
# ('Braveheart', '(1995)', None)
# ('Das Boot', '(1981)', None)
# ('Avengers: Endgame', '(2019)', None)
# ('Mononoke-hime', '(1997)', None)
# ('Once Upon a Time in America', '(1984)', None)
# ('Good Will Hunting', '(1997)', None)
# ('Kimi no na wa.', '(2016)', None)
# ('3 Idiots', '(2009)', None)
# ("Singin' in the Rain", '(1952)', None)
# ('Requiem for a Dream', '(2000)', None)
# ('Tengoku to jigoku', '(1963)', None)
# ('Toy Story 3', '(2010)', None)
# ('Capharnaüm', '(2018)', None)
# ('Star Wars: Episode VI - Return of the Jedi', '(1983)', None)
# ('Eternal Sunshine of the Spotless Mind', '(2004)', None)
# ('2001: A Space Odyssey', '(1968)', None)
# ('Reservoir Dogs', '(1992)', None)
# ('Idi i smotri', '(1985)', None)
# ('Jagten', '(2012)', None)
# ('Citizen Kane', '(1941)', None)
# ('M - Eine Stadt sucht einen Mörder', '(1931)', None)
# ('Lawrence of Arabia', '(1962)', None)
# ('North by Northwest', '(1959)', None)
# ('Ikiru', '(1952)', None)
# ('Vertigo', '(1958)', None)
# ('The Apartment', '(1960)', None)
# ("Le fabuleux destin d'Amélie Poulain", '(2001)', None)
# ('A Clockwork Orange', '(1971)', None)
# ('Double Indemnity', '(1944)', None)
# ('Full Metal Jacket', '(1987)', None)
# ('Scarface', '(1983)', None)
# ('Hamilton', '(2020)', None)
# ('Top Gun: Maverick', '(2022)', None)
# ('Incendies', '(2010)', None)
# ('To Kill a Mockingbird', '(1962)', None)
# ('Heat', '(1995)', None)
# ('The Sting', '(1973)', None)
# ('Up', '(2009)', None)
# ('Jodaeiye Nader az Simin', '(2011)', None)
# ('Metropolis', '(1927)', None)
# ('Taxi Driver', '(1976)', None)
# ('L.A. Confidential', '(1997)', None)
# ('Die Hard', '(1988)', None)
# ('Snatch', '(2000)', None)
# ('Indiana Jones and the Last Crusade', '(1989)', None)
# ('Ladri di biciclette', '(1948)', None)
# ('Taare Zameen Par', '(2007)', None)
# ('1917', '(2019)', None)
# ('Der Untergang', '(2004)', None)
# ('Dangal', '(2016)', None)
# ('Per qualche dollaro in più', '(1965)', None)
# ('Batman Begins', '(2005)', None)
# ('The Kid', '(1921)', None)
# ('Some Like It Hot', '(1959)', None)
# ('The Father', '(2020)', None)
# ('All About Eve', '(1950)', None)
# ('The Wolf of Wall Street', '(2013)', None)
# ('Green Book', '(2018)', None)
# ('Judgment at Nuremberg', '(1961)', None)
# ('Casino', '(1995)', None)
# ('Ran', '(1985)', None)
# ("Pan's Labyrinth", '(2006)', None)
# ('The Truman Show', '(1998)', None)
# ('There Will Be Blood', '(2007)', None)
# ('Unforgiven', '(1992)', None)
# ('The Sixth Sense', '(1999)', None)
# ('Shutter Island', '(2010)', None)
# ('A Beautiful Mind', '(2001)', None)
# ('Jurassic Park', '(1993)', None)
# ('Yôjinbô', '(1961)', None)
# ('The Treasure of the Sierra Madre', '(1948)', None)
# ('Monty Python and the Holy Grail', '(1975)', None)
# ('The Great Escape', '(1963)', None)
# ('No Country for Old Men', '(2007)', None)
# ('Kill Bill: Vol. 1', '(2003)', None)
# ('Rashômon', '(1950)', None)
# ('Spider-Man: No Way Home', '(2021)', None)
# ('The Thing', '(1982)', None)
# ('Finding Nemo', '(2003)', None)
# ('The Elephant Man', '(1980)', None)
# ('Chinatown', '(1974)', None)
# ('Raging Bull', '(1980)', None)
# ('V for Vendetta', '(2005)', None)
# ('Gone with the Wind', '(1939)', None)
# ('Lock, Stock and Two Smoking Barrels', '(1998)', None)
# ('Inside Out', '(2015)', None)
# ('Dial M for Murder', '(1954)', None)
# ('El secreto de sus ojos', '(2009)', None)
# ('Hauru no ugoku shiro', '(2004)', None)
# ('Three Billboards Outside Ebbing, Missouri', '(2017)', None)
# ('The Bridge on the River Kwai', '(1957)', None)
# ('Trainspotting', '(1996)', None)
# ('Prisoners', '(2013)', None)
# ('Warrior', '(2011)', None)
# ('Fargo', '(1996)', None)
# ('Gran Torino', '(2008)', None)
# ('Tonari no Totoro', '(1988)', None)
# ('Catch Me If You Can', '(2002)', None)
# ('Million Dollar Baby', '(2004)', None)
# ('Bacheha-Ye aseman', '(1997)', None)
# ('Blade Runner', '(1982)', None)
# ('The Gold Rush', '(1925)', None)
# ('Before Sunrise', '(1995)', None)
# ('Klaus', '(2019)', None)
# ('12 Years a Slave', '(2013)', None)
# ('Harry Potter and the Deathly Hallows: Part 2', '(2011)', None)
# ('On the Waterfront', '(1954)', None)
# ('Ben-Hur', '(1959)', None)
# ('The Grand Budapest Hotel', '(2014)', None)
# ('Gone Girl', '(2014)', None)
# ('Smultronstället', '(1957)', None)
# ('The General', '(1926)', None)
# ('The Third Man', '(1949)', None)
# ('In the Name of the Father', '(1993)', None)
# ('The Deer Hunter', '(1978)', None)
# ('Barry Lyndon', '(1975)', None)
# ('Hacksaw Ridge', '(2016)', None)
# ('Le salaire de la peur', '(1953)', None)
# ('Salinui chueok', '(2003)', None)
# ('Sherlock Jr.', '(1924)', None)
# ('Relatos salvajes', '(2014)', None)
# ('Mr. Smith Goes to Washington', '(1939)', None)
# ('Mad Max: Fury Road', '(2015)', None)
# ('Det sjunde inseglet', '(1957)', None)
# ('Mary and Max.', '(2009)', None)
# ('How to Train Your Dragon', '(2010)', None)
# ('Room', '(2015)', None)
# ('Monsters, Inc.', '(2001)', None)
# ('Jaws', '(1975)', None)
# ('Dead Poets Society', '(1989)', None)
# ('The Big Lebowski', '(1998)', None)
# ('Tôkyô monogatari', '(1953)', None)
# ("La passion de Jeanne d'Arc", '(1928)', None)
# ('Hotel Rwanda', '(2004)', None)
# ('Ford v Ferrari', '(2019)', None)
# ('Rocky', '(1976)', None)
# ('Platoon', '(1986)', None)
# ('Ratatouille', '(2007)', None)
# ('Spotlight', '(2015)', None)
# ('The Terminator', '(1984)', None)
# ('Logan', '(2017)', None)
# ('Stand by Me', '(1986)', None)
# ('Rush', '(2013)', None)
# ('Network', '(1976)', None)
# ('Before Sunset', '(2004)', None)
# ('Into the Wild', '(2007)', None)
# ('The Wizard of Oz', '(1939)', None)
# ('Pather Panchali', '(1955)', None)
# ('Groundhog Day', '(1993)', None)
# ('The Best Years of Our Lives', '(1946)', None)
# ('The Exorcist', '(1973)', None)
# ('To Be or Not to Be', '(1942)', None)
# ('The Incredibles', '(2004)', None)
# ('La haine', '(1995)', None)
# ('Pirates of the Caribbean: The Curse of the Black Pearl', '(2003)', None)
# ('La battaglia di Algeri', '(1966)', None)
# ('Jai Bhim', '(2021)', None)
# ('The Grapes of Wrath', '(1940)', None)
# ("Hachi: A Dog's Tale", '(2009)', None)
# ('Babam ve Oglum', '(2005)', None)
# ('Rebecca', '(1940)', None)
# ('Amores perros', '(2000)', None)
# ('Cool Hand Luke', '(1967)', None)
# ('Ah-ga-ssi', '(2016)', None)
# ('Les quatre cents coups', '(1959)', None)
# ('The Sound of Music', '(1965)', None)
# ('It Happened One Night', '(1934)', None)
# ('Persona', '(1966)', None)
# ('Life of Brian', '(1979)', None)
# ('The Iron Giant', '(1999)', None)
# ('Dersu Uzala', '(1975)', None)
# ('The Help', '(2011)', None)
# ('Aladdin', '(1992)', None)
# ('Gandhi', '(1982)', None)
# ('Dances with Wolves', '(1990)', None)

# %% [markdown]
# - save the file and run it from the terminal using
# `python filename.py`
